# %% [markdown]
# # Install All Required Libraries
#
# Run the cell below to install all packages:

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Verify Installation

# %%
import PIL
import numpy
import cv2
import gradio
import rembg

print("✓ All packages installed successfully!")
